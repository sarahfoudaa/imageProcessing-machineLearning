# %%
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('../DATA/rainbow.jpg',0) #0--> to read it as a gray scal image

# %%
plt.imshow(img,cmap='gray')

# %%
255/2
# Out:
# 127.5

# %%
#any value that is bellow 127 will be shifter to 0 & above than 127 will be shifter to 255
#ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
#any value that is bellow 127 will be shifter to 255 & above than 127 will be shifter to 0
#ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)
#if the original value is bigger than the threshold,it bring it down to the threshold, if less than the threshold it leave it as it is
#ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_TRUNC)
#if the original value is less than the threshold,it bring it down to the threshold, if bigger than the threshold it leave it as it is
ret, thresh1 = cv2.threshold(img, 127, 255, cv2.THRESH_TOZERO)

# %%
ret
# Out:
# 127.0

# %%
plt.imshow(thresh1,cmap= 'gray')

# %%
img = cv2.imread('../DATA/crossword.jpg',0)

# %%
plt.imshow(img,cmap='gray')

# %%
def show_pic(img):
    fig = plt.figure(figsize=(15,15))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap= 'gray')

# %%
show_pic(img)

# %%
ret, th1 = cv2.threshold(img,180,255,cv2.THRESH_BINARY)
show_pic(th1)

# %%
th2 = cv2.adaptiveThreshold(img, 255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, 11,8)
show_pic(th2)

# %%
#blending the 2 imgs
blender = cv2.addWeighted(src1 = th1, alpha=0.8, src2 = th2, beta=0.4, gamma=0)
show_pic(blender)
