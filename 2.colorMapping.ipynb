# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %%
img = cv2.imread('D:/semester_7/project1/cityScape2/Reference/gtFine/Train/aachen/aachen_000000_000019_gtFine_labelIds.png')
img2 = cv2.imread('D:/semester_7/project1/cityScape2/Reference/gtFine/Train/aachen/aachen_000001_000019_gtFine_labelIds.png')

# %%
plt.imshow(img)

# %%
len(np.unique(img))
# Out:
# 16

# %%
#img

# %%
uniq = np.unique(img)

# %%
uniq
# Out:
# array([ 0,  1,  3,  4,  7,  8, 11, 17, 20, 21, 22, 23, 24, 25, 26, 33],
#       dtype=uint8)

# %%
plt.imshow(img2)

# %%
len(np.unique(img2))
# Out:
# 18

# %%
uniq = np.unique(img2)

# %%
uniq
# Out:
# array([ 0,  1,  3,  4,  5,  6,  7,  8, 11, 12, 13, 17, 19, 20, 21, 22, 23,
#        26], dtype=uint8)

# %%
print(img.size)
print(img2.size)
print(img3.size)
# Out:
# 6291456
# 6291456
# 6291456

# %%
print(np.amin(img))
print(np.amin(img2))
print(np.amin(img3))
# Out:
# 0
# 0
# 0

# %%
print(np.amax(img))
print(np.amax(img2))
print(np.amax(img3))
# Out:
# 33
# 244
# 255

# %%
print(img.shape)
print(img2.shape)
print(img3.shape)
# Out:
# (1024, 2048, 3)
# (1024, 2048, 3)
# (1024, 2048, 3)

# %%
imgg = cv2.imread('D:/semester_7/project1/cityScape2/Reference/gtFine/Train/aachen/aachen_000000_000019_gtFine_labelIds.png',0)
img2g = cv2.imread("D:/semester_7/project1/cityScape2-woextras/Reference/gtFine/Val/frankfurt/frankfurt_000000_000294_gtFine_color.png",0)
img3g = cv2.imread("D:/semester_7/project1/cityScape2-wb/Input/Train/aachen/aachen_000000_000019_leftImg8bit.png",0)

# %%
print(imgg.size)
print(img2g.size)
print(img3g.size)
# Out:
# 2097152
# 2097152
# 2097152

# %%
print(np.amin(imgg))
print(np.amin(img2g))
print(np.amin(img3g))
# Out:
# 0
# 0
# 21

# %%
print(imgg.shape)
print(img2g.shape)
print(img3g.shape)
# Out:
# (1024, 2048)
# (1024, 2048)
# (1024, 2048)

# %%
print(np.amax(imgg))
print(np.amax(img2g))
print(np.amax(img3g))
# Out:
# 33
# 194
# 255

# %%
len(np.unique(imgg))
# Out:
# 16

# %%
img = cv2.imread('D:/semester_7/project1/cityScape2/Reference/gtFine/Train/aachen/aachen_000000_000019_gtFine_labelIds.png')
img2 = cv2.imread("D:/semester_7/project1/cityScape2-woextras/Reference/gtFine/Val/frankfurt/frankfurt_000000_000294_gtFine_color.png")
img3 = cv2.imread("D:/semester_7/project1/cityScape2-wb/Input/Train/aachen/aachen_000000_000019_leftImg8bit.png")

# %%
plt.imshow(img)

# %%
img.shape
# Out:
# (1024, 2048, 3)

# %%
plt.imshow(img2)

# %%
imgg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(imgg)

# %%
imgg = cv2.cvtColor(imgg, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(imgg)

# %%
plt.imshow(imgg)

# %%
plt.imshow(img3)

# %%
img3.shape
# Out:
# (1024, 2048, 3)

# %%
img3gs = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img3gs)

# %%
img3gs.shape
# Out:
# (1024, 2048)

# %%
imgg.size
# Out:
# 2097152

# %%
img.size
# Out:
# 6291456

# %%
+

# %%
img.size
# Out:
# 6291456

# %%
minn = np.amin(img2)

# %%
minn
# Out:
# 0

# %%
maxx = np.amax(img2)

# %%
maxx
# Out:
# 244

# %%
len(np.unique(img2))
# Out:
# 16

# %%
img.shape
# Out:
# (1024, 2048, 3)

# %%
uniq = np.unique(img2)

# %%
uniq
# Out:
# array([  0,  20,  35,  60,  64,  70, 107, 128, 130, 142, 153, 180, 190,
#        220, 232, 244], dtype=uint8)

# %%
img = cv2.imread('D:/semester_7/project1/cityScape2/Reference/gtFine/Train/aachen/aachen_000000_000019_gtFine_labelIds.png')

# %%
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %%
img = cv2.cvtColor(img, cv2.COLOR_RGB2HSV)
plt.imshow(img)
